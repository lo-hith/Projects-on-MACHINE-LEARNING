# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("E:/ppts/machine learning/data.csv")
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
##This describes the information wahts is present in the data set
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
X=data.iloc[:,1:31].values
X
# Out:
# array([['M', 17.99, 10.38, ..., 0.7119, 0.2654, 0.4601],
#        ['M', 20.57, 17.77, ..., 0.2416, 0.18600000000000003, 0.275],
#        ['M', 19.69, 21.25, ..., 0.4504, 0.243, 0.3613],
#        ...,
#        ['M', 16.6, 28.08, ..., 0.3403, 0.1418, 0.2218],
#        ['M', 20.6, 29.33, ..., 0.9387, 0.265, 0.4087],
#        ['B', 7.76, 24.54, ..., 0.0, 0.0, 0.2871]], dtype=object)

# %%
Y = data.iloc[:, 31].values
Y
# Out:
# array([0.1189 , 0.08902, 0.08758, 0.173  , 0.07678, 0.1244 , 0.08368,
#        0.1151 , 0.1072 , 0.2075 , 0.08452, 0.1048 , 0.1023 , 0.06287,
#        0.1431 , 0.1341 , 0.08216, 0.1142 , 0.07615, 0.07259, 0.08183,
#        0.07773, 0.09946, 0.07526, 0.09564, 0.1059 , 0.1275 , 0.07421,
#        0.09876, 0.07919, 0.09782, 0.1402 , 0.08482, 0.1123 , 0.1233 ,
#        0.08633, 0.1014 , 0.06169, 0.05504, 0.1071 , 0.07146, 0.09606,
#        0.1038 , 0.1027 , 0.09618, 0.09185, 0.07409, 0.1179 , 0.08301,
#        0.06917, 0.06563, 0.08025, 0.07408, 0.07987, 0.07873, 0.07036,
#        0.08294, 0.1094 , 0.06289, 0.09026, 0.0802 , 0.07712, 0.1132 ,
#        0.0849 , 0.1031 , 0.08911, 0.09211, 0.06641, 0.1175 , 0.0641 ,
#        0.06589, 0.1084 , 0.1339 , 0.103  , 0.07609, 0.06387, 0.07191,
#        0.1108 , 0.09964, 0.07918, 0.08851, 0.1016 , 0.1051 , 0.09203,
#        0.07924, 0.08579, 0.06846, 0.09288, 0.09261, 0.08473, 0.07246,
# ...

# %%
## we can examine and find the first rows of data set by using head()
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
#It defines the shape of the data set which means how many rows and columns does a dataset contains.
data.shape
# Out:
# (569, 33)

# %%
#As this diagnosis column is the one we have to predict as this one depending on other columns.
data['diagnosis']
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
#this defines wether there is any null,na values in a data set
# if there are na  or null values we will them with median,mode or mean value of the column.
data.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
#It describes the data frame
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# ##now here we are going to plot different plottings using the data set by using different nuclues

# %%
##Plotting Radius of Cell ( mean , standard error, worst)
radius=data[['radius_mean','radius_se','radius_worst','diagnosis']]
radius
sns.pairplot(radius,hue="diagnosis")

# %%
##Plotting texture of Cell ( mean , standard error, worst)

texture = data[['texture_mean','texture_se','texture_worst','diagnosis']]
sns.pairplot(texture, hue='diagnosis')

# %%
##Plotting perimeter of Cell ( mean , standard error, worst)
perimeter=data[['perimeter_mean','perimeter_se','perimeter_worst','diagnosis']]
sns.pairplot(perimeter, hue='diagnosis')

# %%
##Plotting area of Cell ( mean , standard error, worst)
area = data[['area_mean','area_se','area_worst','diagnosis']]
sns.pairplot(area, hue='diagnosis')

# %%
##Plotting smoothness of Cell ( mean , standard error, worst)
smoothness = data[['smoothness_mean','smoothness_se','smoothness_worst','diagnosis']]
sns.pairplot(smoothness, hue='diagnosis')

# %%
##Plotting compactness of Cell ( mean , standard error, worst)
compactness=data[['compactness_mean','compactness_se','compactness_worst','diagnosis']]
sns.pairplot(compactness, hue='diagnosis')

# %%
##Plotting concavity of Cell ( mean , standard error, worst)

concavity = data[['concavity_mean','concavity_se','concavity_worst','diagnosis']]
sns.pairplot(concavity, hue='diagnosis')

# %%
##Plotting concave_points of Cell ( mean , standard error, worst)
concave_points = data[['concave points_mean','concave points_se','concave points_worst','diagnosis']]
sns.pairplot(concave_points, hue='diagnosis')

# %%
##Plotting symmetry of Cell ( mean , standard error, worst)
symmetry = data[['symmetry_mean','symmetry_se','symmetry_worst','diagnosis']]
sns.pairplot(symmetry, hue='diagnosis')

# %%
##Plotting fractal_dimension of Cell ( mean , standard error, worst)

fractal_dimension = data[['fractal_dimension_mean','fractal_dimension_se','fractal_dimension_worst','diagnosis']]
sns.pairplot(fractal_dimension, hue='diagnosis')

# %%
# Calculating Numbers of Labels of Class 'M'  and 'B'
# Plotting lables
Label =data['diagnosis']
a =pd.DataFrame(Label.value_counts())
print(a)
a.plot(kind='barh')
# Out:
#    diagnosis
# B        357
# M        212

# %% [markdown]
# #Categorical data are variables that contain label values rather than numeric values.The number of possible values is often limited to a fixed set
# So we use OneHot Coding to create categorical data into numeric data type.

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_Y = LabelEncoder()
Y = labelencoder_Y.fit_transform(X['diagnosis'])
Y
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-57-33b397a49204> in <module>
#       1 from sklearn.preprocessing import LabelEncoder
#       2 labelencoder_Y = LabelEncoder()
# ----> 3 Y = labelencoder_Y.fit_transform(X['diagnosis'])
#       4 Y
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
# fit and transform the data frame using le on town column
data.diagnosis = le.fit_transform(data.diagnosis)
data.diagnosis
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int32

# %%
data
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %%
X=data.iloc[:,1:31].values
X
# Out:
# array([[ 1.    , 17.99  , 10.38  , ...,  0.7119,  0.2654,  0.4601],
#        [ 1.    , 20.57  , 17.77  , ...,  0.2416,  0.186 ,  0.275 ],
#        [ 1.    , 19.69  , 21.25  , ...,  0.4504,  0.243 ,  0.3613],
#        ...,
#        [ 1.    , 16.6   , 28.08  , ...,  0.3403,  0.1418,  0.2218],
#        [ 1.    , 20.6   , 29.33  , ...,  0.9387,  0.265 ,  0.4087],
#        [ 0.    ,  7.76  , 24.54  , ...,  0.    ,  0.    ,  0.2871]])

# %%
Y = data.iloc[:, 31].values
Y
# Out:
# array([0.1189 , 0.08902, 0.08758, 0.173  , 0.07678, 0.1244 , 0.08368,
#        0.1151 , 0.1072 , 0.2075 , 0.08452, 0.1048 , 0.1023 , 0.06287,
#        0.1431 , 0.1341 , 0.08216, 0.1142 , 0.07615, 0.07259, 0.08183,
#        0.07773, 0.09946, 0.07526, 0.09564, 0.1059 , 0.1275 , 0.07421,
#        0.09876, 0.07919, 0.09782, 0.1402 , 0.08482, 0.1123 , 0.1233 ,
#        0.08633, 0.1014 , 0.06169, 0.05504, 0.1071 , 0.07146, 0.09606,
#        0.1038 , 0.1027 , 0.09618, 0.09185, 0.07409, 0.1179 , 0.08301,
#        0.06917, 0.06563, 0.08025, 0.07408, 0.07987, 0.07873, 0.07036,
#        0.08294, 0.1094 , 0.06289, 0.09026, 0.0802 , 0.07712, 0.1132 ,
#        0.0849 , 0.1031 , 0.08911, 0.09211, 0.06641, 0.1175 , 0.0641 ,
#        0.06589, 0.1084 , 0.1339 , 0.103  , 0.07609, 0.06387, 0.07191,
#        0.1108 , 0.09964, 0.07918, 0.08851, 0.1016 , 0.1051 , 0.09203,
#        0.07924, 0.08579, 0.06846, 0.09288, 0.09261, 0.08473, 0.07246,
# ...

# %%
# train the computer Using Linear Regression Model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
reg = LinearRegression()
reg.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Y_pred = reg.predict(X_test)
Y_pred
# Out:
# array([0.11012449, 0.06795269, 0.06515721, 0.07646414, 0.05980623,
#        0.07134783, 0.09649039, 0.07240589, 0.09960476, 0.08384543,
#        0.09326012, 0.0716099 , 0.08880222, 0.0583278 , 0.08136154,
#        0.103441  , 0.11004836, 0.07825021, 0.07222058, 0.08037614,
#        0.1376925 , 0.10108322, 0.08805931, 0.07885989, 0.08196572,
#        0.07176796, 0.07165129, 0.14081054, 0.07426246, 0.10073496,
#        0.07331901, 0.07828108, 0.08734176, 0.08153165, 0.07944362,
#        0.10369049, 0.07124458, 0.06570954, 0.06965872, 0.08998799,
#        0.0608019 , 0.0755407 , 0.0772171 , 0.07509704, 0.11511393,
#        0.07033333, 0.080934  , 0.07298942, 0.06549621, 0.13012798,
#        0.10443238, 0.09154647, 0.07978633, 0.07792684, 0.07627059,
#        0.08096143, 0.0708611 , 0.06638436, 0.06800056, 0.0890853 ,
#        0.09297651, 0.06819479, 0.0700936 , 0.07219458, 0.11751439,
#        0.0663628 , 0.10109752, 0.08808931, 0.05909968, 0.08877227,
# ...

# %%
r2_score(Y_test, Y_pred) #93.30 accuracy
# Out:
# 0.9330162363112893

# %% [markdown]
# #CONCLUSION
# So finally we have built our classification model and we can see that Linear Regression algorithm gives the best results for our dataset. Well its not always applicable to every dataset. To choose our model we always need to analyze our dataset and then apply our machine learning model.
